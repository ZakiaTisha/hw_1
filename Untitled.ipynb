# %%
class subject():
    def__init__(self, name, mark):
        self.name = name
        self.mark = mark
    def grade_point(self):
        if 80<=self.mark<=100:
            return 4
        elif 60<=self.mark<=79:
            return 3
        elif 40<=self.mark<=59:
            return 2
        else:
            return 0
    
    def grade(self):
        if 80<=self.mark<=100:
            return "A"
        elif 60<=self.mark<=79:
            return "B"
        elif 40<=self.mark<=59:
            return "C"
        else:
            return "F"
# Out:
#   File "<ipython-input-5-b6a061738c9c>", line 2
#     def__init__(self, name, mark):
#                                   ^
# SyntaxError: invalid syntax

# %%
a, b, c = input("Enter numbers: ").split()
print(a, b, c)
# Out:
# Enter numbers: 1 3 56
# 1 3 56
